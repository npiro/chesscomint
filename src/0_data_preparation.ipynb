# %% [markdown]
# # 0 - Data Preparation
#
# This notebook contains command-line steps to extract the raw datasets used by the modeling notebooks.
#
# Expected outputs:
#
# - `../data/raw/titled_tuesday_games.jsonl`
# - `../data/raw/titled_tuesday_players.jsonl`

# %%
# %%bash
# set -euo pipefail
#
# # Run from `src/`.
# pwd

# %%
# %%bash
# set -euo pipefail
#
# # Ensure output directories exist.
# mkdir -p ../data/raw ../data/processed

# %%
# %%bash
# set -euo pipefail
#
# # Fetch both tournament games and player stats.
# PYTHONPATH=. python3 -m chesscomint.fetch_data \
#   --user-agent "chesscomint-interview-exercise (contact: you@example.com)"

# %%
# %%bash
# set -euo pipefail
#
# # (Optional) Refresh only player rows from an existing games file.
# PYTHONPATH=. python3 -m chesscomint.fetch_data \
#   --players-only \
#   --games-input ../data/raw/titled_tuesday_games.jsonl \
#   --players-output ../data/raw/titled_tuesday_players.jsonl \
#   --user-agent "chesscomint-interview-exercise (contact: you@example.com)"

# %%
# %%bash
# set -euo pipefail
#
# # Verify generated files.
# ls -lh ../data/raw/titled_tuesday_games.jsonl ../data/raw/titled_tuesday_players.jsonl
